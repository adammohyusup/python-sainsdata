# %% [markdown]
# # TEMA : Data COVID-19 di indonesia

# %% [markdown]
# ## Anggota kelompok
# - 10122206 - Farhan Fahrezi Santosa    (Kontribusi : Scrapping)
# - 10122208 - Fila Desta Andanda        (Kontribusi : Visualisasi)
# - 10122212 - Kevin Juniawan            (Kontribusi : Tampilan Aplikasi)
# - 10122220 - Adam Mohamad Yusup Hanapi (Kontribusi : Geographic Information system)
# - 10122224 – JEC FAREN SITUMORANG      (Kontribusi : visualisasi)

# %% [markdown]
# ## Foto dokumentasi
# ![tubes_pds.jpg](attachment:fdd364e1-62b8-4fd9-a7ad-a9bbaaadbbb1.jpg)

# %% [markdown]
# ## latar belakang dan tujuan
# - latar belakang  :
# Pada 2020, pandemi COVID-19 melanda dunia, termasuk Indonesia. Penyebaran virus ini memicu respons pemerintah dan masyarakat untuk                       mengatasi dampaknya
# - Tujuan          : Pembuatan data COVID-19 di Indonesia bertujuan untuk memberikan informasi akurat dan terkini tentang perkembangan pandemi. Tujuannya                     meliputi pemantauan, pengambilan keputusan, kesadaran masyarakat, dan keterbukaan pemerintah dalam menangani situasi ini. Data ini                       menjadi dasar untuk langkah-langkah pencegahan dan penanganan yang efektif..

# %% [markdown]
# ## List module yang digunakan

# %%
pip install streamlit numpy plotly matplotlib plotly-express pydeck altair seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Scrapping Data

# %%
# !kaggle datasets list -s 'indonesia'
# Out:
# ref                                                          title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# -----------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# ardisragen/indonesia-coronavirus-cases                       Indonesia-Coronavirus                                10KB  2020-04-15 11:15:41          12647        201  0.9411765
# hendratno/covid19-indonesia                                  COVID-19 Indonesia Dataset                            1MB  2022-09-17 06:34:57          33692        413  1.0
# aprabowo/indonesia-tourism-destination                       Indonesia Tourism Destination                       158KB  2021-07-21 13:02:11          10714        106  0.8235294
# ...

# %%
import kaggle
import pandas as pd

kaggle.api.authenticate()

kaggle.api.dataset_download_files('hendratno/covid19-indonesia', path='./dataset', unzip=True)

df = pd.read_csv('covid_19_indonesia_time_series_all.csv')

df
# Out:
#             Date Location ISO Code          Location  New Cases  New Deaths  \
# 0       3/1/2020             ID-JK       DKI Jakarta          2           0
# 1       3/2/2020             ID-JK       DKI Jakarta          2           0
# 2       3/2/2020               IDN         Indonesia          2           0
# 3       3/2/2020             ID-RI              Riau          1           0
# 4       3/3/2020             ID-JK       DKI Jakarta          2           0
# ...          ...               ...               ...        ...         ...
# 31817  9/15/2022             ID-SA    Sulawesi Utara         37           0
# 31818  9/15/2022             ID-SB    Sumatera Barat         13           0
# 31819  9/15/2022             ID-SS  Sumatera Selatan         16           0
# 31820  9/15/2022             ID-SU    Sumatera Utara         50           0
# 31821  9/16/2022               IDN         Indonesia       2358          27
#
# ...

# %%
import pandas as pd

# %%
covid = pd.read_csv("covid_19_indonesia_time_series_all.csv")

# %%
covid
# Out:
#             Date Location ISO Code          Location  New Cases  New Deaths  \
# 0       3/1/2020             ID-JK       DKI Jakarta          2           0
# 1       3/2/2020             ID-JK       DKI Jakarta          2           0
# 2       3/2/2020               IDN         Indonesia          2           0
# 3       3/2/2020             ID-RI              Riau          1           0
# 4       3/3/2020             ID-JK       DKI Jakarta          2           0
# ...          ...               ...               ...        ...         ...
# 31817  9/15/2022             ID-SA    Sulawesi Utara         37           0
# 31818  9/15/2022             ID-SB    Sumatera Barat         13           0
# 31819  9/15/2022             ID-SS  Sumatera Selatan         16           0
# 31820  9/15/2022             ID-SU    Sumatera Utara         50           0
# 31821  9/16/2022               IDN         Indonesia       2358          27
#
# ...

# %% [markdown]
# ## Visualisasi Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


data = pd.read_csv('covid_19_indonesia_time_series_all.csv')

x_var = 'Location'
y_var = 'Total Cases'

data_filtered = data[data['Location'] != 'Indonesia']

data_filtered = data_filtered.sort_values(by=y_var, ascending=False)

plt.figure(figsize=(12, 8))
sns.barplot(x=x_var, y=y_var, data=data_filtered, palette='Spectral', hue=x_var, dodge=False, legend=False)

# Customize the chart
plt.title(f'Total Cases by {x_var} (excluding Indonesia)')
plt.xlabel(x_var)
plt.ylabel(y_var)
plt.xticks(rotation=45, ha='right')  
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('covid_19_indonesia_time_series_all.csv')

print(data.head())

x_var = 'Location'  

y_var = 'Total Cases'  


data_filtered = data[data['Location'] != 'Indonesia']

data_filtered = data_filtered.sort_values(by=y_var, ascending=False)

plt.figure(figsize=(12, 8))  
sns.barplot(x=x_var, y=y_var, data=data_filtered, palette='Spectral', hue=x_var, dodge=False, legend=False)

plt.title('Total Cases by Location (excluding Indonesia)')
plt.xlabel(x_var)
plt.ylabel(y_var)
plt.xticks(rotation=45, ha='right')  
plt.tight_layout()  
plt.show()
# Out:
#        Date Location ISO Code     Location  New Cases  New Deaths  \
# 0  3/1/2020             ID-JK  DKI Jakarta          2           0
# 1  3/2/2020             ID-JK  DKI Jakarta          2           0
# 2  3/2/2020               IDN    Indonesia          2           0
# 3  3/2/2020             ID-RI         Riau          1           0
# 4  3/3/2020             ID-JK  DKI Jakarta          2           0
#
#    New Recovered  New Active Cases  Total Cases  Total Deaths  \
# 0              0                 2           39            20
# 1              0                 2           41            20
# 2              0                 2            2             0
# 3              0                 1            1             0
# 4              0                 2           43            20
#
#    Total Recovered  ...  Latitude New Cases per Million  \
# 0               75  ... -6.204699                  0.18
# 1               75  ... -6.204699                  0.18
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('covid_19_indonesia_time_series_all.csv')

data_filtered = data[data['Location'] != 'Indonesia']

x_var = 'Location'  

y_var = 'New Cases'  

plt.figure(figsize=(12, 6))
sns.barplot(x=x_var, y=y_var, data=data_filtered, palette='viridis', hue=x_var, dodge=False, legend=False)

plt.title('New Cases by Location')
plt.xlabel(x_var)
plt.ylabel(y_var)
plt.xticks(rotation=45, ha='right')  

plt.tight_layout()  

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('covid_19_indonesia_time_series_all.csv')

data_filtered = data[data['Location'] != 'Indonesia']

total_cases_by_location = data_filtered.groupby('Location')['Total Cases'].max()

total_cases_all_locations = total_cases_by_location.sum()

percentage_total_cases = (total_cases_by_location / total_cases_all_locations) * 100

plt.figure(figsize=(10, 10))
plt.pie(percentage_total_cases, labels=percentage_total_cases.index, autopct="%1.1f%%", labeldistance=1.1)
plt.title("Percentage of Total Cases by Location")

plt.axis('equal')  

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('covid_19_indonesia_time_series_all.csv')

x_axis = "Date"
y_axis = "Total Cases"

data_filtered = data[data['Location'] != 'Indonesia']

grouped_data = data_filtered.groupby("Location")[y_axis]

plt.figure(figsize=(10, 6))
for name, group_data in grouped_data:
    plt.plot(group_data.index, group_data.values, label=name)

plt.title(f"{y_axis} over {x_axis} (excluding Indonesia)")
plt.xlabel(x_axis)
plt.ylabel(y_axis)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left') 
plt.grid(True)
plt.tight_layout()  

plt.show()

# %% [markdown]
# ## GIS

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import numpy as np
import seaborn as sns
import textwrap
import matplotlib.pyplot as plt
import datetime
from datetime import date

# %%
df = pd.read_csv("covid_19_indonesia_time_series_all.csv")
covid_df = df.copy()
covid_df.head()
# Out:
#        Date Location ISO Code     Location  New Cases  New Deaths  \
# 0  3/1/2020             ID-JK  DKI Jakarta          2           0
# 1  3/2/2020             ID-JK  DKI Jakarta          2           0
# 2  3/2/2020               IDN    Indonesia          2           0
# 3  3/2/2020             ID-RI         Riau          1           0
# 4  3/3/2020             ID-JK  DKI Jakarta          2           0
#
#    New Recovered  New Active Cases  Total Cases  Total Deaths  \
# 0              0                 2           39            20
# 1              0                 2           41            20
# 2              0                 2            2             0
# 3              0                 1            1             0
# 4              0                 2           43            20
#
#    Total Recovered  ...  Latitude New Cases per Million  \
# 0               75  ... -6.204699                  0.18
# 1               75  ... -6.204699                  0.18
# ...

# %%
date2 =[]
for item in covid_df['Date']:
    item2=item.split('/')
    month=int(item2[0])
    day=int(item2[1])
    year=int(item2[2])
    date2+=[datetime.date(year,month,day)]
covid_df['Date']=date2
covid_df['Date'] = pd.to_datetime(df['Date'])
covid_df.head()
# Out:
#         Date Location ISO Code     Location  New Cases  New Deaths  \
# 0 2020-03-01             ID-JK  DKI Jakarta          2           0
# 1 2020-03-02             ID-JK  DKI Jakarta          2           0
# 2 2020-03-02               IDN    Indonesia          2           0
# 3 2020-03-02             ID-RI         Riau          1           0
# 4 2020-03-03             ID-JK  DKI Jakarta          2           0
#
#    New Recovered  New Active Cases  Total Cases  Total Deaths  \
# 0              0                 2           39            20
# 1              0                 2           41            20
# 2              0                 2            2             0
# 3              0                 1            1             0
# 4              0                 2           43            20
#
#    Total Recovered  ...  Latitude New Cases per Million  \
# 0               75  ... -6.204699                  0.18
# 1               75  ... -6.204699                  0.18
# ...

# %%
covid_df.drop(["Location ISO Code", "New Cases", "New Deaths", "New Recovered", "New Active Cases", "Province", "Country", "Continent", "Island", "Time Zone", 
                "Special Status", "Total Regencies", "Total Cities", "Total Districts", "Total Urban Villages", "Total Rural Villages", "Area (km2)", 
                "New Cases per Million", "Total Cases per Million","New Deaths per Million", "Total Deaths per Million", "Case Fatality Rate",
                "Case Recovered Rate", "Growth Factor of New Cases","Growth Factor of New Deaths", "City or Regency"],axis=1,inplace=True)

# %%
covid_newest = covid_df.drop_duplicates(subset='Location', keep="last").copy()
covid_newest.head()
# Out:
#             Date        Location  Total Cases  Total Deaths  Total Recovered  \
# 31759 2022-09-14       Gorontalo        13951           487            13433
# 31780 2022-09-14  Sulawesi Barat        15601           394            15201
# 31788 2022-09-15            Aceh        44038          2223            41713
# 31789 2022-09-15            Bali       166831          4731           161629
# 31790 2022-09-15          Banten       333875          2950           328482
#
#        Total Active Cases Location Level  Population  Population Density  \
# 31759                  31       Province     1180651              104.88
# 31780                   6       Province     1559984               92.93
# 31788                 102       Province     5247257               90.54
# 31789                 471       Province     4216171              729.43
# 31790                2443       Province    10722374             1109.64
#
#         Longitude  Latitude  Total Deaths per 100rb
# ...

# %%
data_geo = gpd.read_file('gadm36_IDN_3.shp')
data_geo.drop(["NAME_0"],axis=1,inplace=True)
data_geo.rename(columns = {"NAME_1":"Provinsi"}, inplace = True)
data_geo['Provinsi'].replace({"Jakarta Raya":"DKI Jakarta"},inplace=True)
data_geo.head()
# Out:
#   GID_0    GID_1 Provinsi NL_NAME_1      GID_2      NAME_2 NL_NAME_2  \
# 0   IDN  IDN.1_1     Aceh      None  IDN.1.2_1  Aceh Barat      None
# 1   IDN  IDN.1_1     Aceh      None  IDN.1.2_1  Aceh Barat      None
# 2   IDN  IDN.1_1     Aceh      None  IDN.1.2_1  Aceh Barat      None
# 3   IDN  IDN.1_1     Aceh      None  IDN.1.2_1  Aceh Barat      None
# 4   IDN  IDN.1_1     Aceh      None  IDN.1.2_1  Aceh Barat      None
#
#          GID_3            NAME_3 VARNAME_3 NL_NAME_3     TYPE_3     ENGTYPE_3  \
# 0  IDN.1.2.1_1  Arongan Lambalek      None      None  Kecamatan  Sub-district
# 1  IDN.1.2.2_1             Bubon      None      None  Kecamatan  Sub-district
# 2  IDN.1.2.3_1    Johan Pahlawan      None      None  Kecamatan  Sub-district
# 3  IDN.1.2.4_1         Kaway Xvi      None      None  Kecamatan  Sub-district
# 4  IDN.1.2.5_1          Meureubo      None      None  Kecamatan  Sub-district
#
#       CC_3 HASC_3                                           geometry
# ...

# %%
covid_newest.rename(columns={'Location':'Provinsi'},inplace=True)
covid_newest
# Out:
#             Date                    Provinsi  Total Cases  Total Deaths  \
# 31759 2022-09-14                   Gorontalo        13951           487
# 31780 2022-09-14              Sulawesi Barat        15601           394
# 31788 2022-09-15                        Aceh        44038          2223
# 31789 2022-09-15                        Bali       166831          4731
# 31790 2022-09-15                      Banten       333875          2950
# 31791 2022-09-15                    Bengkulu        29173           522
# 31792 2022-09-15                 DKI Jakarta      1412511         15513
# 31793 2022-09-15  Daerah Istimewa Yogyakarta       224307          5928
# 31795 2022-09-15                       Jambi        38643           889
# 31796 2022-09-15                  Jawa Barat      1173731         15937
# 31797 2022-09-15                 Jawa Tengah       636409         33489
# 31798 2022-09-15                  Jawa Timur       601545         31764
# ...

# %%
covid_peta = data_geo.merge(covid_newest.sort_values(by='Provinsi'),on='Provinsi')
covid_peta
# Out:
#      GID_0     GID_1        Provinsi NL_NAME_1        GID_2        NAME_2  \
# 0      IDN   IDN.1_1            Aceh      None    IDN.1.2_1    Aceh Barat
# 1      IDN   IDN.1_1            Aceh      None    IDN.1.2_1    Aceh Barat
# 2      IDN   IDN.1_1            Aceh      None    IDN.1.2_1    Aceh Barat
# 3      IDN   IDN.1_1            Aceh      None    IDN.1.2_1    Aceh Barat
# 4      IDN   IDN.1_1            Aceh      None    IDN.1.2_1    Aceh Barat
# ...    ...       ...             ...       ...          ...           ...
# 6570   IDN  IDN.32_1  Sumatera Utara      None  IDN.32.34_1  Toba Samosir
# 6571   IDN  IDN.32_1  Sumatera Utara      None  IDN.32.34_1  Toba Samosir
# 6572   IDN  IDN.32_1  Sumatera Utara      None  IDN.32.34_1  Toba Samosir
# 6573   IDN  IDN.32_1  Sumatera Utara      None  IDN.32.34_1  Toba Samosir
# 6574   IDN  IDN.32_1  Sumatera Utara      None  IDN.32.34_1  Toba Samosir
#
#      NL_NAME_2           GID_3             NAME_3 VARNAME_3  ... Total Cases  \
# ...

# %%
fig,ax = plt.subplots(4,figsize=(36,36))
plt.style.use('ggplot')
covid_peta.plot(column='Total Cases',cmap='Reds',figsize=(9,36),legend=True,ax=ax[0])
ax[0].set_title('Total kasus',fontsize=25)
covid_peta.plot(column='Total Deaths',cmap='Purples',figsize=(9,36),legend=True,ax=ax[1])
ax[1].set_title('Total Kematian',fontsize=25)
covid_peta.plot(column='Total Recovered',cmap='Greens',figsize=(9,36),legend=True,ax=ax[2])
ax[2].set_title('Total Sembuh',fontsize=25)
covid_peta.plot(column='Total Active Cases',cmap='Blues',figsize=(9,36),legend=True,ax=ax[3])
ax[3].set_title('Total Kasus Aktif',fontsize=25)

#add background color
ax[0].set_facecolor('#e0e0e0')
ax[1].set_facecolor('#e0e0e0')
ax[2].set_facecolor('#e0e0e0')
ax[3].set_facecolor('#e0e0e0')

for i in np.arange(4):
    ax[i].spines['top'].set_visible(False)
    ax[i].spines['right'].set_visible(False)
    ax[i].spines['left'].set_visible(False)
    ax[i].spines['bottom'].set_visible(False)
    for item in ax[i].get_xticklabels():
        item.set_visible(False)
    for item in ax[i].get_yticklabels():
        item.set_visible(False)
    ax[i].set_xticks([])
    ax[i].set_yticks([])
fig.suptitle('Peta Covid-19 Indonesia', fontsize=18)
# Out:
# Text(0.5, 0.98, 'Peta Covid-19 Indonesia')
